# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
name = "model-2"

l1 = np.load(name+"-train.npy")
l2 = np.load(name+"-val.npy")
l3 = np.load(name+"-test.npy")

print(np.min(l2),l3[np.argmin(l2)])
# Out:
# 276.12077154636836 249.53365490350612

# %%
plt.figure(figsize=(18,12))
plt.title(name+' Loss')
plt.plot(np.log(l1)[:256], color='aqua', label='Train Loss')
plt.plot(np.log(l2)[:256], color='violet', label='Valid Loss')
plt.plot(np.log(l3)[:256], color='greenyellow', label='Test Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18,12))
plt.title(name+' PPL')
plt.plot(l1[:256], color='aqua', label='Train PPL')
plt.plot(l2[:256], color='violet', label='Valid PPL')
plt.plot(l3[:256], color='greenyellow', label='Test PPL')
plt.legend()
plt.show()

# %%
np.log(np.array([0.001,1,2]))
# Out:
# array([-6.90775528,  0.        ,  0.69314718])
